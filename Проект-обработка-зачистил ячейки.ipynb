# %%
#импортируем необходимые библиотеки
import pandas as pd
import pandas_profiling
import sqlite3

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#1) Прочитать корректно файл в виде датафрейма. Разрешается работать с файлом только через Jupyter Notebook
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_customers_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить наименование столбцов
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Данные высокого качества, без дубликатов.
# customer_id - значения на 100% уникальные, без пропусков.
# customer_unique_id - значения на 96,6% уникальные, без пропусков.
# customer_zip_code_prefix - значения без пропусков, уникальных значений 15,1%.
# customer_city - значения без пропусков, уникальных значений 4,1%.
# customer_state - значения без пропусков, уникальных значений менее 0,1%.

# %%
#6) Проверить данные на пустые значения. 
# При необходимости удалить или заменить пустые значения. 
# Чистовые значения можно заменять на среднее или медианное значение, категориальные атрибуты заменять на «не определено» - НЕ ПОНЯЛ ЗАДАЧИ.
df.isnull().sum()

# %%
#7) Проверить данные на дубликаты. При необходимости удалить дубликаты из датафрейма
df[df.duplicated()].sort_values('customer_id')

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_customers_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_customers_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_geolocation_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить наименование столбцов
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# В данных есть 12,8% дубликатов.
# geolocation_zip_code_prefix - уникальных значений 1,9%, без пропусков.
# geolocation_lat - уникальных значений 71,1%, без пропусков.
# geolocation_lng - уникальных значений 71,7%, без пропусков.
# geolocation_city - уникальных значений 0,8%, без пропусков, есть различия в написании букв, ошибки в словах.
# geolocation_state - уникальных значений менее 0,1%, без пропусков.

# %%
# Настройка отображения всех строк
pd.set_option('display.max_rows', None)

# %%
# Подсчет упоминаний названия 
value_counts = df['geolocation_city'].value_counts()
value_counts

# %%
#9) Заменить данные
df['geolocation_city'] = df['geolocation_city'].str.replace('á', 'a', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('â', 'a', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('ã', 'a', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('à', 'a', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('ç', 'c', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('é', 'e', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('ê', 'e', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('í', 'i', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('ó', 'o', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('ô', 'o', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('õ', 'o', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('ú', 'u', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('horizonta', 'horizonte', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('goytacaze', 'goytacazes', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('ceara mirim', 'ceara-mirim', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("d  oeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("d oeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("d' oeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("d' oeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("doeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("d%26apos%3boeste", "d'oeste", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("do oeste mg", "do oeste", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('embu guacu', 'embu-guacu', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('embuguacu', 'embu-guacu', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('franca sp', 'franca', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('guarulhos-sp', 'guarulhos', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('gurarapes', 'guararapes', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('jundia', 'jundiai', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('maceia³', 'maceio', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('mogidascruzes', 'mogi das cruzes', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('mogi-guacu', 'mogi guacu', case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace('mogi-mirim', 'mogi mirim', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("d agua", "d'agua", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("dagua", "d'agua", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("olho-d agua do borges", "olho-d'agua do borges", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("d  arco", "d'arco", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('pindare mirim', 'pindare-mirim', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('aelgre', 'alegre', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('presidente castello branco', 'presidente castelo branco', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('bracnco', 'branco', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace('rio de janeiro, rio de janeiro, brasil', 'rio de janeiro', case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("santa rita do oeste", "santa rita d'oeste", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("sant'ana", "santana", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("d alianca", "d'alianca", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("dalianca", "d'alianca", case=False)

df['geolocation_city'] = df['geolocation_city'].str.replace("d alho", "d'alho", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("d%26apos%3balho", "d'alho", case=False)
df['geolocation_city'] = df['geolocation_city'].str.replace("dalho", "d'alho", case=False)

df['geolocation_city'] = df['geolocation_city'].replace('sao luiz', 'sao luis')

df['geolocation_city'] = df['geolocation_city'].str.replace('saopaulo', 'sao paulo', case=False)

df['geolocation_city'] = df['geolocation_city'].replace('venda nova do imigrante-es', 'venda nova do imigrante')

df['geolocation_city'] = df['geolocation_city'].replace('vila bela da santssima trindade', 'vila bela da santissima trindade')

df['geolocation_city'] = df['geolocation_city'].replace('xangrila', 'xangri-la')

df['geolocation_city'] = df['geolocation_city'].replace('4o. centenario', '4º centenario')

# %%
#повторно пересчитываю названия и вижу их количественное изменение
value_counts = df['geolocation_city'].value_counts()
value_counts

# %%
# повторно запустить отчет профайлинга и проанализировать его результаты
df.profile_report()

# %%
# Проверяем дубликаты в столбцах 
duplicates = df.duplicated(subset=['geolocation_zip_code_prefix', 'geolocation_lat','geolocation_lng'], keep=False)
print(df[duplicates])

# %%
#подсчет дубликатов по количеству
duplicate_counts = df.groupby(['geolocation_zip_code_prefix', 'geolocation_lat','geolocation_lng']).size().reset_index(name='counts')
print(duplicate_counts[duplicate_counts['counts'] > 1])

# %%
#удаление дубликатов
df= df.drop_duplicates(subset=['geolocation_lat','geolocation_lng'])
print(df)

# %%
#Проверить количество строк и столбцов
df.shape

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_geolocation_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_geolocation_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_order_items_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) проверить наименование столбцоа
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
# меняю тип данных для столбца
df['shipping_limit_date'] = pd.to_datetime(df['shipping_limit_date'])

# %%
df.info()

# %%
df.head()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Данные высокого качества, без дубликатов.
# order_id - уникальных значений 87,6%, без пропусков. Текстовые данные.
# order_item_id - уникальных значений <0,1%, без пропусков. Числовые данные (целые числа).
# product_id - уникальных значений 29,3%, без пропусков. Текстовые данные.
# seller_id - уникальных значений 2,7%, без пропусков. Текстовые данные.
# shipping_limit_date - уникальных значений 82,8%, без пропусков. Даты.
# price - уникальных значений 5,3%, без пропусков. Числовые данные (десятичные числа).
# freight_value - уникальных значений 5,3%, без пропусков. Числовые данные (десятичные числа).

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_order_items_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_order_items_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_order_payments_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Данные без дубликатов и пропущенных ячеек.Есть одно предупреждение - payment_type очень несбалансированный столбец (52.6%).
# order_id - уникальных значений 95,7%, без пропусков. Текстовые данные.
# payment_sequential - 29 уникальных значений, <0,1% от общего количества строк, без пропусков. Числовые данные.
# payment_type - несбалансированные столбец (сильный перекос по значению credit_card относительно других, скорее всего связано со распространненым способом оплаты на маркетплейсе). 5 уникальных значений, <0,1% от общего количества столбцов. Категориальные данные (текст).
# payment_installments - 24 уникальных значения, <0,1% от общего числа строк, без пропусков. Числовые данные (целые числа).

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_order_payments_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_order_payments_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_order_reviews_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
# меняю типы данных для двух столбцов с датой
df['review_creation_date'] = pd.to_datetime(df['review_creation_date'])
df['review_answer_timestamp'] = pd.to_datetime(df['review_answer_timestamp'])

# %%
df.info()

# %%
df.head()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Много пропущенных ячеек, дубликатов нет.
# Есть два предупреждения:
# - review_comment_title - 87656 (88.3%) пропущенных значений
# - review_comment_message - 58247 (58.7%) пропущенных значений
# review_id - уникальных значений 98410, 99,2%, без пропусков. Текстовые данные.
# order_id - 98763 уникальных значений, 99,4% от общего количества строк, без пропусков. Текстовые данные.
# review_score - 5 уникальных значений, <0,1% от общего количества столбцов. Категориальные данные (числа - оценки).
# review_comment_title - 4527 уникальных значения, 39,1% от заполненного числа строк, 87656 пропусков (88,3% от общего числа строк). Текстовые данные (отзывы).
# review_comment_message - 36159 уникальных значений, 88,2% от заполненных строк, 58247 пропущенных строк (58,7% от общего числа). Текстовые данные.
# review_creation_date - 636 значений, 0,6% уникальных, без пропусков строк. Дата.
# review_answer_timestamp - 98248 значений, 99% уникальных, без пропусков. Дата.

# %%
#6) Проверить данные на пустые значения. 
# видно, что пустые значения относятся к названию комментирия и самому комментарию.
df.isnull().sum()

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_order_reviews_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_order_reviews_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_orders_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#меняю типы данных в формат даты для нескольких столбцов
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_approved_at'] = pd.to_datetime(df['order_approved_at'])
df['order_delivered_carrier_date'] = pd.to_datetime(df['order_delivered_carrier_date'])
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'])

# %%
df.info()

# %%
df.head()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Есть пять предупреждений:
# - order_status - высокая несбалансированность (91.4%)
# - order_delivered_carrier_date - 1783 (1.8%) пропущенных значений
# - order_delivered_customer_date - 2965 (3.0%) пропущенных значений
# - order_id - уникальные значения
# - customer_id - уникальные значения
# order_id - идентификатор заказа 99441 (100%) уникальных значений, без пропусков. Так как уникальность идентификатора заказов является необходимым условием для проведения анализа данных, то предупреждение носит рекомендательный характер ("обратить внимание").
# customer_id - идентификатор заказа 99441 (100%) уникальных значений, без пропусков. Видимо система присваивает каждому клиенту уникальный идентификатор для каждого заказа, поэтому предупреждение носит рекомендательный характер ("обратить внимание").
# order_status - статус заказа - 8 уникальных значений, несбалансированность связана с большим количеством доставленных заказов, относительно заказов с другими статусами. Категориальные данные (статусы заказов).
# order_purchase_timestamp - дата и время покупки - 98875 уникальных значений, без пропусков строк. Данные в формате даты.
# order_approved_at - дата и время одобрения заказа - 90733 уникальных значений, есть пропуски строк 160 (0,2%). Видимо, не все заказы обработаны.
# order_delivered_carrier_date - дата доставки заказа поставщиком - 81018 уникальных значений, 1763 пропущенных строки (1,8%), не ясно с чем связаны пропуски данных. Данные в формате даты.
# order_delivered_customer_date - дата доставки заказа покупателю - 95664 уникальных значения, 2965 пропущенных строк (3%). Данные в формате даты.
# order_estimated_delivery_date - дата предполагаемой доставки - 459 значений, без пропусков. Данные в формате даты.
#
# Не ясно с чем связаны пропуски значений order_delivered_carrier_date и order_delivered_customer_date.

# %%
# Проверяю данные на пустые значения. 
# видно, что пустые значения относятся к датам, не трогаю
df.isnull().sum()

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_orders_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_orders_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_products_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Есть девять предупреждений:
# - product_weight_g высокая корреляция с product_length_cm и еще 2мя столбцами
# - product_length_cm высокая корреляция с product_weight_g и еще одним столбцом
# - product_height_cm высокая корреляция с product_weight_g
# - product_width_cm высокая корреляция с product_weight_g и еще одним столбцом
# - product_category_name - 610 (1.9%) пропущенных значений
# - product_name_lenght - 610 (1.9%) пропущенных значений
# - product_description_lenght - 610 (1.9%) пропущенных значений
# - product_photos_qty has 610 (1.9%) пропущенных значений
# - product_id - уникальные значения
# product_id - идентификатор товаров 32951 (100%) уникальных значений, без пропусков. Так как уникальность идентификатора товаров (в таблице товаров) является необходимым условием для проведения анализа данных, то предупреждение носит рекомендательный характер ("обратить внимание").
# product_category_name - категория продукта - 73 уникальных значения, 610 пропущенных строк (1,9%). Текстовые данные.
# product_name_lenght - длина наименования товара - 66 уникальных значений (0,2%), 610 пропущенных строк (1,9%). Данные в целочисленном формате.
# product_description_lenght - длина описания товара - 2960 уникальных значений (9,2%), 610 пропущенных строк (1,9%). Данные в целочисленном формате.
# product_photos_qty - количество фото товара - 19 уникальных значений (0,1%), 610 пропущенных строк (1,9%).
# product_weight_g - вес продукта в гр - 2204 уникальных значения (6,7%), 2 пропущенных строки (<0,1%). Данные в целочисленном формате. Высокая корреляция с нижеописанными параметрами связана с зависимостью габаритов товара и его весом (как правило, больше размер - больше вес).
# roduct_length_cm - длина товара, см - 99 уникальных значений, 2 пропущенных строки (<0,1%). анные в целочисленном формате. Есть взаимосвязь с product_weight_g и другими габаритами товара.
# product_height_cm - высота товара, см - 102 уникальных значения (0,3%), 2 пропущенных строки (<0,1%). Данные в целочисленном формате. Есть взаимосвязь с product_weight_g и другими габаритами товара.
# product_width_cm - ширина товара, см - 95 уникальных значений (0,3%), 2 пропущенных строки (<0,1%). Данные в целочисленном формате. Есть взаимосвязь с product_weight_g и другими габаритами товара.
#
# Не ясно с чем связаны пропуски значений, но видна взаимосвязь и соответствие по количеству.

# %%
# Проверяю данные на пустые значения. 
# видно, что пустые значения относятся к названию комментирия и самому комментарию.
df.isnull().sum()

# %%
#смотрим пустые значения в данных, ЧТО ДЕЛАТЬ С ДАННЫМИ ЗНАЧЕНИЯМИ?
df[df.isna().any(axis=1)]

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_products_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_products_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/olist_sellers_dataset.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Есть четыре предупреждения:
# - seller_zip_code_prefix высокая корреляция с seller_state
# - seller_state высокая корреляция с seller_zip_code_prefix
# - seller_state высокая несбалансированность (52.5%)
# - seller_id - уникальные значения
# seller_id - идентификатор продавцов - 3095 (100%) уникальных значений, без пропусков. Так как уникальность идентификатора продавцов (в таблице продавцов) является необходимым условием для проведения анализа данных, то предупреждение носит рекомендательный характер ("обратить внимание"). Текстовый формат данных.
# seller_zip_code_prefix - префикс почтового индекса - 2246 уникальных значения (72,6%), без пропусков. Данные в целочисленном формате. Коррелируют с seller_state (штат продавца), так как данные напрямую связаны (штат и почтовый индекс).
# seller_city - город продавца - 611 уникальных значений, без пропусков. Написание названий некоторых городов содержит опечатки или ошибки.
# seller_state - штат продавца - 23 уникальных значения (0,7%), без пропусков. Высокая корреляция с eller_zip_code_prefix и высокая несбалансированность (связана с большой разницей в плотности продавцов в разных штатах).

# %%
value_counts = df['seller_city'].value_counts()
value_counts

# %% [markdown]
# Написание названий некоторых городов содержит опечатки или ошибки.

# %%
df['seller_city'] = df['seller_city'].replace('angra dos reis rj', 'angra dos reis')
df['seller_city'] = df['seller_city'].replace('auriflama/sp', 'auriflama')
df['seller_city'] = df['seller_city'].replace('balenario camboriu', 'balneario camboriu')
df['seller_city'] = df['seller_city'].replace('belo horizont', 'belo horizonte')
df['seller_city'] = df['seller_city'].replace('brasilia df', 'brasilia')
df['seller_city'] = df['seller_city'].replace('barbacena/ minas gerais', 'barbacena')
df['seller_city'] = df['seller_city'].replace('carapicuiba / sao paulo', 'carapicuiba')
df['seller_city'] = df['seller_city'].replace('cariacica / es', 'cariacica')
df['seller_city'] = df['seller_city'].replace('cascavael', 'cascavel')
df['seller_city'] = df['seller_city'].replace('ferraz de  vasconcelos', 'ferraz de vasconcelos')
df['seller_city'] = df['seller_city'].replace('jacarei / sao paulo', 'jacarei')
df['seller_city'] = df['seller_city'].replace('lages - sc', 'lages')
df['seller_city'] = df['seller_city'].replace('maua/sao paulo', 'maua')
df['seller_city'] = df['seller_city'].replace('mogi das cruzes / sp', 'mogi das cruzes')
df['seller_city'] = df['seller_city'].replace('mogi das cruses', 'mogi das cruzes')
df['seller_city'] = df['seller_city'].replace('novo hamburgo, rio grande do sul, brasil', 'novo hamburgo')
df['seller_city'] = df['seller_city'].replace('pinhais/pr', 'pinhais')
df['seller_city'] = df['seller_city'].replace('portoferreira', 'porto ferreira')
df['seller_city'] = df['seller_city'].replace('ribeirao preto / sao paulo', 'ribeirao preto')
df['seller_city'] = df['seller_city'].replace('ribeirao pretp', 'ribeirao preto')
df['seller_city'] = df['seller_city'].replace('riberao preto', 'ribeirao preto')
df['seller_city'] = df['seller_city'].replace('rio de janeiro / rio de janeiro', 'rio de janeiro')
df['seller_city'] = df['seller_city'].replace('rio de janeiro \rio de janeiro', 'rio de janeiro')
df['seller_city'] = df['seller_city'].replace('rio de janeiro, rio de janeiro, brasil', 'rio de janeiro')
df['seller_city'] = df['seller_city'].replace('s jose do rio preto', 'sao jose do rio preto')
df['seller_city'] = df['seller_city'].replace("santa barbara d oeste", "santa barbara d'oeste")
df['seller_city'] = df['seller_city'].replace("santa barbara d´oeste", "santa barbara d'oeste")
df['seller_city'] = df['seller_city'].replace('santo andre/sao paulo', 'santo andre')
df['seller_city'] = df['seller_city'].replace('sao bernardo do capo', 'sao bernardo do campo')
df['seller_city'] = df['seller_city'].replace('sao jose do rio pret', 'sao jose do rio preto')
df['seller_city'] = df['seller_city'].replace('sao jose dos pinhas', 'sao jose dos pinhais')

df['seller_city'] = df['seller_city'].replace('sao paluo', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('são paulo', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('sao paulo - sp', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('sao paulo / sao paulo', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('sao paulo sp', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('sao paulop', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('sao pauo', 'sao paulo')

df['seller_city'] = df['seller_city'].replace('sao sebastiao da grama/sp', 'sao sebastiao da grama')
df['seller_city'] = df['seller_city'].replace('sbc/sp', 'sbc')
df['seller_city'] = df['seller_city'].replace('sp / sp', 'sp ')

df['seller_city'] = df['seller_city'].replace('vendas@creditparts.com.br', 'not defined')
df['seller_city'] = df['seller_city'].replace('04482255', 'not defined')

# %%
value_counts = df['seller_city'].value_counts()
value_counts

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_sellers_dataset',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_sellers_dataset.xlsx", index=False)

# %%
# Чтение файла в датафрейм
df = pd.read_csv('!Brazilian E-Commerce Public Dataset by Olist/product_category_name_translation.csv')

# Вывод первых строк для проверки
df.head()

# %%
#2) Проверить количество строк и столбцов
df.shape

# %%
#3) Проверить название колонн
df.columns

# %%
#4) Проверить типы данных
df.info()

# %%
#5) Запустить отчет профайлинга и проанализировать его результаты, написать тезисно результаты в ноутбуке
df.profile_report()

# %% [markdown]
# Есть два предупреждения об уникальности значений в столбцах:
# - product_category_name
# - product_category_name_english
# product_category_name - наименование категории продукта - 71 уникальное значение (100%), без пропусков. Данные в формате текста.
# product_category_name_english - наименование категории продукта на английском - 71 уникальное значение (100%), без пропусков. Данные в формате текста.
#
# Предупреждение об уникальности значений в обоих столбцах носит рекомендательный характер.

# %%
# Подключаемся к базе данных (если файла нет, он будет создан)
conn = sqlite3.connect('project_olist.db')

# Создаём курсор
cursor = conn.cursor()

# %%
 # Загружаем DataFrame в таблицу 
df.to_sql(
            name='project_olist_product_category_name_translation',
            con=conn,
            if_exists='append',  # Добавляем данные в существующую таблицу
            index=False
        )

# %%
#Выгружаем преобразованный датафрейм в excel файл

# Выгружаем DataFrame в файл Excel
df.to_excel("project_olist_product_category_name_translation.xlsx", index=False)
